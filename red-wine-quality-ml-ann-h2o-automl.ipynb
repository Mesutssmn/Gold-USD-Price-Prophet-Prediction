# %% [markdown]
# <a href="https://www.kaggle.com/code/mesutssmn/red-wine-quality-ml-ann-h2o-automl?scriptVersionId=172025308" target="_blank"><img align="left" alt="Kaggle" title="Open in Kaggle" src="https://kaggle.com/static/images/open-in-kaggle.svg"></a>

# %% [markdown]
# <div style="border-radius:40px; border:#5E5772 solid; padding: 12px; background-color: #FFB6C1; font-size:150%; text-align:left">
#
# <h3 align="center"><font color='#800000' size=150%>Red Wine Quality</font></h3>
#
#
# * Cleaning dataset for classification
# * Some analysis and statistics
# * ML, ANN, AutoML
#
# * Red wine is a type of wine made from dark-colored grape varieties. The color of the wine can range from intense violet, typical of young wines, through to brick red for mature wines and brown for older red wines. The juice from most purple grapes is greenish-white, the red color coming from anthocyan pigments present in the skin of the grape. Much of the red wine production process involves extraction of color and flavor components from the grape skin.
#
#
# <div style="border-radius: 10px; overflow: hidden; text-align: center;">
#     <img src="https://www.thespruceeats.com/thmb/1RzqbsX3m-SJR_yFrMhpRwBhkCQ=/750x0/filters:no_upscale():max_bytes(150000):strip_icc():format(webp)/red-wine-is-poured-into-a-glass-from-a-bottle--light-background--1153158143-98320451802c485cb6d7b5437c7fd60a.jpg" alt="Red Wine" width="700">
# </div>

# %% [markdown]
# # <div style="border-radius:10px; border:#5E5772 solid; padding: 12px; background-color: #FFB6C1; font-size:100%; font-family:Comic Sans MS; font-family:Comic Sans MS; text-align:center"> AUTHOR </p>
#
# #### **Name :** Mesut Suhan Şişman
# - **Social Link :**
#
# <div style="text-align: left;">
#  <table>
#   <tr>
#     <th><b>Website</b></th>
#     <th><b>Links</b></th>
#     </tr>
#     <tr>
#     </tr>
#     <tr>
#     <td>GitHub</td>
#     <td><a href="https://github.com/Mesutssmn"><img src="https://img.shields.io/badge/GitHub-Profile-blue?style=for-the-badge&logo=github" alt="GitHub"/></a></td>
#     </tr>
#     <tr>
#     <td>LinkedIn</td>
#     <td><a href="https://www.linkedin.com/in/mesut-suhan-%C5%9Fi%C5%9Fman-6ab69b123/"><img src="https://img.shields.io/badge/LinkedIn-Profile-blue?style=for-the-badge&logo=linkedin" alt="LinkedIn"/></a></td>
#     </tr>
#     <tr>
#     </tr>
#     <tr>

# %% [markdown]
# # <div style="border-radius:10px; border:#5E5772 solid; padding: 12px; background-color: #FFB6C1; font-size:100%; font-family:Comic Sans MS; font-family:Comic Sans MS; text-align:center"> IMPORTINGS </p>

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
import statsmodels.api as sm
import statsmodels.formula.api as smf
from sklearn.linear_model import LogisticRegression
from sklearn.ensemble import RandomForestClassifier
from sklearn.tree import DecisionTreeClassifier
from sklearn.neighbors import KNeighborsClassifier
from xgboost import XGBClassifier
from sklearn.ensemble import AdaBoostClassifier
from sklearn.naive_bayes import GaussianNB
from sklearn.ensemble import GradientBoostingClassifier
from sklearn.svm import SVC
from tabulate import tabulate
from sklearn.preprocessing import MinMaxScaler,StandardScaler, LabelEncoder, OneHotEncoder
from sklearn.metrics import classification_report,confusion_matrix,mean_squared_error,accuracy_score,recall_score,precision_score,f1_score,roc_auc_score
from sklearn.model_selection import train_test_split, cross_val_score,GridSearchCV
from catboost import CatBoostClassifier
from lightgbm import LGBMClassifier
import warnings
warnings.filterwarnings("ignore")

# %%
pd.set_option('display.max_columns', None)
pd.set_option('display.width', None)
pd.set_option('display.max_rows', 55)
pd.set_option('display.float_format', lambda x: '%.3f' % x)

# %% [markdown]
# # <div style="border-radius:10px; border:#5E5772 solid; padding: 12px; background-color: #FFB6C1; font-size:100%; font-family:Comic Sans MS; font-family:Comic Sans MS; text-align:center"> LOADING DATA </p>

# %%
df = pd.read_csv('/kaggle/input/red-wine-quality-cortez-et-al-2009/winequality-red.csv')
df.head()
# Out:
#    fixed acidity  volatile acidity  citric acid  residual sugar  chlorides  \
# 0          7.400             0.700        0.000           1.900      0.076
# 1          7.800             0.880        0.000           2.600      0.098
# 2          7.800             0.760        0.040           2.300      0.092
# 3         11.200             0.280        0.560           1.900      0.075
# 4          7.400             0.700        0.000           1.900      0.076
#
#    free sulfur dioxide  total sulfur dioxide  density    pH  sulphates  \
# 0               11.000                34.000    0.998 3.510      0.560
# 1               25.000                67.000    0.997 3.200      0.680
# 2               15.000                54.000    0.997 3.260      0.650
# 3               17.000                60.000    0.998 3.160      0.580
# 4               11.000                34.000    0.998 3.510      0.560
#
#    alcohol  quality
# 0    9.400        5
# 1    9.800        5
# 2    9.800        5
# 3    9.800        6
# 4    9.400        5

# %% [markdown]
# <div style="border-radius:10px; border:#5E5772 solid; padding: 12px; background-color: #FFB6C1; font-size:100%; text-align:center">
# <p style=" font-size:250% ; text-align:center" > FEATURES </p>
#
#
#
# 1. **Fixed Acidity:**  Represents the total amount of acids in the wine. Acidity can affect the taste and stability of the wine.
#
# 2. **Volatile Acidity:** Indicates the amount of acetic acid in the wine. High levels can lead to an unpleasant vinegar taste.
#
# 3. **Citric Acid:** Found in small quantities, citric acid can add freshness and flavor to the wine. It can also act as a preservative.
#
# 4. **Residual Sugar:** Refers to the amount of sugar left in the wine after fermentation. Affects the sweetness of the wine; higher levels result in sweeter wines.
#
# 5. **Chlorides:** Represents the amount of salt in the wine. Too much chloride can make the wine taste salty or briny.
#
# 6. **Free Sulfur Dioxide:** Acts as an antioxidant and preservative. Helps prevent microbial growth and oxidation.
#
# 7. **Total Sulfur Dioxide:** Sum of both free and bound forms of sulfur dioxide. Important for wine stability and shelf-life.
#
# 8. **Density:** Refers to the mass of the wine per unit volume. Can be an indicator of sugar content or alcohol content.
#
# 9. **pH:** Measures the acidity or alkalinity of the wine. pH affects the taste, color, and stability of the wine.
#
# 10. **Sulphates:** Sulfur compounds that can act as antioxidants and antimicrobial agents. Can contribute to the wine's flavor and aroma.
#
# 11. **Alcohol:** Represents the alcohol content of the wine. Alcohol affects the body, sweetness, and overall balance of the wine.
#
# 12. **Quality:** Score between 0 and 10 indicating the quality of the wine. This is the target variable you want to predict based on the input features.

# %% [markdown]
# # <div style="border-radius:10px; border:#5E5772 solid; padding: 12px; background-color: #FFB6C1; font-size:100%; font-family:Comic Sans MS; font-family:Comic Sans MS; text-align:center"> DATA OVERVIEW AND GRAB COLS </p>

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1599 entries, 0 to 1598
# Data columns (total 12 columns):
#  #   Column                Non-Null Count  Dtype
# ---  ------                --------------  -----
#  0   fixed acidity         1599 non-null   float64
#  1   volatile acidity      1599 non-null   float64
#  2   citric acid           1599 non-null   float64
#  3   residual sugar        1599 non-null   float64
#  4   chlorides             1599 non-null   float64
#  5   free sulfur dioxide   1599 non-null   float64
#  6   total sulfur dioxide  1599 non-null   float64
#  7   density               1599 non-null   float64
#  8   pH                    1599 non-null   float64
#  9   sulphates             1599 non-null   float64
#  10  alcohol               1599 non-null   float64
#  11  quality               1599 non-null   int64
# dtypes: float64(11), int64(1)
# memory usage: 150.0 KB

# %%
df.quality.unique()
# Out:
# array([5, 6, 7, 4, 8, 3])

# %%
df.quality = df.quality-3
df.quality.unique()
# Out:
# array([2, 3, 4, 1, 5, 0])

# %%
df.head()
# Out:
#    fixed acidity  volatile acidity  citric acid  residual sugar  chlorides  \
# 0          7.400             0.700        0.000           1.900      0.076
# 1          7.800             0.880        0.000           2.600      0.098
# 2          7.800             0.760        0.040           2.300      0.092
# 3         11.200             0.280        0.560           1.900      0.075
# 4          7.400             0.700        0.000           1.900      0.076
#
#    free sulfur dioxide  total sulfur dioxide  density    pH  sulphates  \
# 0               11.000                34.000    0.998 3.510      0.560
# 1               25.000                67.000    0.997 3.200      0.680
# 2               15.000                54.000    0.997 3.260      0.650
# 3               17.000                60.000    0.998 3.160      0.580
# 4               11.000                34.000    0.998 3.510      0.560
#
#    alcohol  quality
# 0    9.400        2
# 1    9.800        2
# 2    9.800        2
# 3    9.800        3
# 4    9.400        2

# %%
def grab_col_names(dataframe, cat_th=10, car_th=20):
    
    # cat_cols, cat_but_car
    cat_cols = [col for col in dataframe.columns if dataframe[col].dtypes == "O"]
    num_but_cat = [col for col in dataframe.columns if dataframe[col].nunique() < cat_th and dataframe[col].dtypes != "O"]
    cat_but_car = [col for col in dataframe.columns if dataframe[col].nunique() > car_th and dataframe[col].dtypes == "O"]
    cat_cols = cat_cols + num_but_cat
    cat_cols = [col for col in cat_cols if col not in cat_but_car]

    # num_cols
    num_cols = [col for col in dataframe.columns if dataframe[col].dtypes != "O"]
    num_cols = [col for col in num_cols if col not in num_but_cat]

    print(f"Observations: {dataframe.shape[0]}")
    print(f"Variables: {dataframe.shape[1]}")
    print(f'cat_cols: {len(cat_cols)}')
    print(f'num_cols: {len(num_cols)}')
    print(f'cat_but_car: {len(cat_but_car)}')
    print(f'num_but_cat: {len(num_but_cat)}')

    return cat_cols, num_cols, cat_but_car


cat_cols, num_cols, cat_but_car = grab_col_names(df)
# Out:
# Observations: 1599
# Variables: 12
# cat_cols: 1
# num_cols: 11
# cat_but_car: 0
# num_but_cat: 1

# %%
cat_cols, num_cols, cat_but_car
# Out:
# (['quality'],
#  ['fixed acidity',
#   'volatile acidity',
#   'citric acid',
#   'residual sugar',
#   'chlorides',
#   'free sulfur dioxide',
#   'total sulfur dioxide',
#   'density',
#   'pH',
#   'sulphates',
#   'alcohol'],
#  [])

# %% [markdown]
# # <div style="border-radius:10px; border:#5E5772 solid; padding: 12px; background-color: #FFB6C1; font-size:100%; font-family:Comic Sans MS; font-family:Comic Sans MS; text-align:center"> VISUALIZATIONS </p>

# %%
def cat_summary(dataframe, col_name, plot=False):
    print(pd.DataFrame({col_name: dataframe[col_name].value_counts(),
                        "Ratio": 100 * dataframe[col_name].value_counts() / len(dataframe)}))

    if plot:
        fig, axs = plt.subplots(1, 2, figsize=(8, 6))
        plt.subplot(1, 2, 1)
        sns.countplot(x=dataframe[col_name], data=dataframe)
        plt.title("Frequency of " + col_name)
        plt.xticks(rotation=90)

        plt.subplot(1, 2, 2)
        values = dataframe[col_name].value_counts()
        plt.pie(x=values, labels=values.index, autopct=lambda p: '{:.2f}% ({:.0f})'.format(p, p/100 * sum(values)))
        plt.title("Frequency of " + col_name)
        plt.legend(labels=['{} - {:.2f}%'.format(index, value/sum(values)*100) for index, value in zip(values.index, values)],
                   loc='upper center', bbox_to_anchor=(0.5, -0.2), fancybox=True, shadow=True, ncol=1)
        plt.show(block=True)

for col in cat_cols:
    cat_summary(df, col, True)
# Out:
#          quality  Ratio
# quality
# 2            681 42.589
# 3            638 39.900
# 4            199 12.445
# 1             53  3.315
# 5             18  1.126
# 0             10  0.625

# %%
import matplotlib.pyplot as plt
import seaborn as sns
import scipy.stats as stats

def num_summary(dataframe, numerical_col, plot=False):
    quantiles = [0.05, 0.10, 0.20, 0.30, 0.40, 0.50, 0.60, 0.70, 0.80, 0.90, 0.95, 0.99]
    print(dataframe[numerical_col].describe(quantiles).T)
    
    if plot:
        fig, axs = plt.subplots(2, 2, figsize=(12, 10))
        
        # Histogram
        plt.subplot(2, 2, 1)
        dataframe[numerical_col].hist(bins=50)
        plt.xlabel(numerical_col)
        plt.title(numerical_col + ' Distribution')
        
        # Boxplot
        plt.subplot(2, 2, 2)
        sns.boxplot(y=numerical_col, data=dataframe)
        plt.title("Boxplot of " + numerical_col)
        plt.xticks(rotation=90)
        
        # Density Plot
        plt.subplot(2, 2, 3)
        sns.kdeplot(dataframe[numerical_col], shade=True)
        plt.xlabel(numerical_col)
        plt.title(numerical_col + ' Density')
        
        # QQ Plot
        plt.subplot(2, 2, 4)
        stats.probplot(dataframe[numerical_col], dist="norm", plot=plt)
        plt.title(numerical_col + ' QQ Plot')
        
        plt.tight_layout()
        plt.show(block=True)
        
    print("#####################################")

for col in num_cols:
    num_summary(df, col, plot=True)
# Out:
# count   1599.000
# mean       8.320
# std        1.741
# min        4.600
# 5%         6.100
# 10%        6.500
# 20%        7.000
# 30%        7.200
# 40%        7.600
# 50%        7.900
# 60%        8.300
# 70%        8.900
# 80%        9.700
# 90%       10.700
# 95%       11.800
# 99%       13.300
# max       15.900
# Name: fixed acidity, dtype: float64
# #####################################
# count   1599.000
# mean       0.528
# std        0.179
# min        0.120
# 5%         0.270
# 10%        0.310
# 20%        0.370
# 30%        0.415
# 40%        0.470
# 50%        0.520
# 60%        0.570
# 70%        0.610
# 80%        0.660
# 90%        0.745
# 95%        0.840
# 99%        1.020
# max        1.580
# Name: volatile acidity, dtype: float64
# #####################################
# count   1599.000
# mean       0.271
# std        0.195
# min        0.000
# 5%         0.000
# 10%        0.010
# 20%        0.070
# 30%        0.124
# 40%        0.210
# 50%        0.260
# 60%        0.320
# 70%        0.390
# 80%        0.460
# 90%        0.522
# 95%        0.600
# 99%        0.700
# max        1.000
# Name: citric acid, dtype: float64
# #####################################
# count   1599.000
# mean       2.539
# std        1.410
# min        0.900
# 5%         1.590
# 10%        1.700
# 20%        1.800
# 30%        2.000
# 40%        2.100
# 50%        2.200
# 60%        2.300
# 70%        2.500
# 80%        2.700
# 90%        3.600
# 95%        5.100
# 99%        8.306
# max       15.500
# Name: residual sugar, dtype: float64
# #####################################
# count   1599.000
# mean       0.087
# std        0.047
# min        0.012
# 5%         0.054
# 10%        0.060
# 20%        0.067
# 30%        0.072
# 40%        0.076
# 50%        0.079
# 60%        0.082
# 70%        0.087
# 80%        0.094
# 90%        0.109
# 95%        0.126
# 99%        0.360
# max        0.611
# Name: chlorides, dtype: float64
# #####################################
# count   1599.000
# mean      15.875
# std       10.460
# min        1.000
# 5%         4.000
# 10%        5.000
# 20%        6.000
# 30%        9.000
# 40%       11.000
# 50%       14.000
# 60%       16.000
# 70%       19.000
# 80%       24.000
# 90%       31.000
# 95%       35.000
# 99%       50.020
# max       72.000
# Name: free sulfur dioxide, dtype: float64
# #####################################
# count   1599.000
# mean      46.468
# std       32.895
# min        6.000
# 5%        11.000
# 10%       14.000
# 20%       19.000
# 30%       24.000
# 40%       30.000
# 50%       38.000
# 60%       45.800
# 70%       55.000
# 80%       69.000
# 90%       93.200
# 95%      112.100
# 99%      145.000
# max      289.000
# Name: total sulfur dioxide, dtype: float64
# #####################################
# count   1599.000
# mean       0.997
# std        0.002
# min        0.990
# 5%         0.994
# 10%        0.995
# 20%        0.995
# 30%        0.996
# 40%        0.996
# 50%        0.997
# 60%        0.997
# 70%        0.998
# 80%        0.998
# 90%        0.999
# 95%        1.000
# 99%        1.002
# max        1.004
# Name: density, dtype: float64
# #####################################
# count   1599.000
# mean       3.311
# std        0.154
# min        2.740
# 5%         3.060
# 10%        3.120
# 20%        3.180
# 30%        3.230
# 40%        3.280
# 50%        3.310
# 60%        3.350
# 70%        3.380
# 80%        3.424
# 90%        3.510
# 95%        3.570
# 99%        3.700
# max        4.010
# Name: pH, dtype: float64
# #####################################
# count   1599.000
# mean       0.658
# std        0.170
# min        0.330
# 5%         0.470
# 10%        0.500
# 20%        0.540
# 30%        0.564
# 40%        0.590
# 50%        0.620
# 60%        0.650
# 70%        0.700
# 80%        0.760
# 90%        0.850
# 95%        0.930
# 99%        1.260
# max        2.000
# Name: sulphates, dtype: float64
# #####################################
# count   1599.000
# mean      10.423
# std        1.066
# min        8.400
# 5%         9.200
# 10%        9.300
# 20%        9.500
# 30%        9.600
# 40%        9.900
# 50%       10.200
# 60%       10.500
# 70%       10.900
# 80%       11.300
# 90%       12.000
# 95%       12.500
# 99%       13.400
# max       14.900
# Name: alcohol, dtype: float64
# #####################################

# %% [markdown]
# # <div style="border-radius:10px; border:#5E5772 solid; padding: 12px; background-color: #FFB6C1; font-size:100%; font-family:Comic Sans MS; font-family:Comic Sans MS; text-align:center"> DATA ANALYSIS </p>

# %%
def target_summary_with_num(dataframe, target, numerical_col):
    print(dataframe.groupby(target).agg({numerical_col: "mean"}), end="\n\n\n")

for col in num_cols:
    target_summary_with_num(df, "quality", col)
# Out:
#          fixed acidity
# quality
# 0                8.360
# 1                7.779
# 2                8.167
# 3                8.347
# 4                8.872
# 5                8.567
#
#
#          volatile acidity
# quality
# 0                   0.885
# 1                   0.694
# 2                   0.577
# 3                   0.497
# 4                   0.404
# 5                   0.423
#
#
#          citric acid
# quality
# 0              0.171
# 1              0.174
# 2              0.244
# 3              0.274
# 4              0.375
# 5              0.391
#
#
#          residual sugar
# quality
# 0                 2.635
# 1                 2.694
# 2                 2.529
# 3                 2.477
# 4                 2.721
# 5                 2.578
#
#
#          chlorides
# quality
# 0            0.122
# 1            0.091
# 2            0.093
# 3            0.085
# 4            0.077
# 5            0.068
#
#
#          free sulfur dioxide
# quality
# 0                     11.000
# 1                     12.264
# 2                     16.984
# 3                     15.712
# 4                     14.045
# 5                     13.278
#
#
#          total sulfur dioxide
# quality
# 0                      24.900
# 1                      36.245
# 2                      56.514
# 3                      40.870
# 4                      35.020
# 5                      33.444
#
#
#          density
# quality
# 0          0.997
# 1          0.997
# 2          0.997
# 3          0.997
# 4          0.996
# 5          0.995
#
#
#            pH
# quality
# 0       3.398
# 1       3.382
# 2       3.305
# 3       3.318
# 4       3.291
# 5       3.267
#
#
#          sulphates
# quality
# 0            0.570
# 1            0.596
# 2            0.621
# 3            0.675
# 4            0.741
# 5            0.768
#
#
#          alcohol
# quality
# 0          9.955
# 1         10.265
# 2          9.900
# 3         10.630
# 4         11.466
# 5         12.094

# %%
corr = df.corr()
sns.set(rc={'figure.figsize': (15, 6)})
sns.heatmap(corr, cmap="Reds", annot=True, fmt=".2f")
plt.show()

# %%
y = df["quality"]
X = df.drop("quality", axis=1)

# %%
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.25, random_state=42)

rf_model = RandomForestClassifier(random_state=42).fit(X_train, y_train)
y_pred = rf_model.predict(X_test)

# %%
rf_model.score(X_train, y_train)
# Out:
# 1.0

# %%
def plot_importance(model, features, num=len(X), save=False):
    feature_imp = pd.DataFrame({'Value': model.feature_importances_, 'Feature': features.columns})
    plt.figure(figsize=(10, 10))
    sns.set(font_scale=1)
    sns.barplot(x="Value", y="Feature", data=feature_imp.sort_values(by="Value",
                                                                     ascending=False)[0:num])
    plt.title('Features')
    plt.tight_layout()
    plt.show()
    if save:
        plt.savefig('importances.png')

plot_importance(rf_model, X)

# %%
def outlier_thresholds(dataframe, col_name, q1=0.05, q3=0.95):
    quartile1 = dataframe[col_name].quantile(q1)
    quartile3 = dataframe[col_name].quantile(q3)
    interquantile_range = quartile3 - quartile1
    up_limit = quartile3 + 1.5 * interquantile_range
    low_limit = quartile1 - 1.5 * interquantile_range
    return low_limit, up_limit

def check_outlier(dataframe, col_name):
    low_limit, up_limit = outlier_thresholds(dataframe, col_name)
    if dataframe[(dataframe[col_name] > up_limit) | (dataframe[col_name] < low_limit)].any(axis=None):
        return True
    else:
        return False

def replace_with_thresholds(dataframe, variable, q1=0.05, q3=0.95):
    low_limit, up_limit = outlier_thresholds(dataframe, variable, q1=0.05, q3=0.95)
    dataframe.loc[(dataframe[variable] < low_limit), variable] = low_limit
    dataframe.loc[(dataframe[variable] > up_limit), variable] = up_limit

# %%
for col in df.columns:
    print(col, check_outlier(df, col))
    if check_outlier(df, col):
        replace_with_thresholds(df, col)
# Out:
# fixed acidity False
# volatile acidity False
# citric acid False
# residual sugar True
# chlorides True
# free sulfur dioxide False
# total sulfur dioxide True
# density False
# pH False
# sulphates True
# alcohol False
# quality False

# %%
for col in df.columns:
    print(col, check_outlier(df, col))
# Out:
# fixed acidity False
# volatile acidity False
# citric acid False
# residual sugar False
# chlorides False
# free sulfur dioxide False
# total sulfur dioxide False
# density False
# pH False
# sulphates False
# alcohol False
# quality False

# %%
df.columns = [col.upper() for col in df.columns]

df.head()
# Out:
#    FIXED ACIDITY  VOLATILE ACIDITY  CITRIC ACID  RESIDUAL SUGAR  CHLORIDES  \
# 0          7.400             0.700        0.000           1.900      0.076
# 1          7.800             0.880        0.000           2.600      0.098
# 2          7.800             0.760        0.040           2.300      0.092
# 3         11.200             0.280        0.560           1.900      0.075
# 4          7.400             0.700        0.000           1.900      0.076
#
#    FREE SULFUR DIOXIDE  TOTAL SULFUR DIOXIDE  DENSITY    PH  SULPHATES  \
# 0               11.000                34.000    0.998 3.510      0.560
# 1               25.000                67.000    0.997 3.200      0.680
# 2               15.000                54.000    0.997 3.260      0.650
# 3               17.000                60.000    0.998 3.160      0.580
# 4               11.000                34.000    0.998 3.510      0.560
#
#    ALCOHOL  QUALITY
# 0    9.400        2
# 1    9.800        2
# 2    9.800        2
# 3    9.800        3
# 4    9.400        2

# %%
df.QUALITY.unique()
# Out:
# array([2, 3, 4, 1, 5, 0])

# %% [markdown]
# # <div style="border-radius:10px; border:#5E5772 solid; padding: 12px; background-color: #FFB6C1; font-size:100%; font-family:Comic Sans MS; font-family:Comic Sans MS; text-align:center"> FEATURE EXTRACTION </p>

# %%
df['TOTAL ACIDITY'] = df['FIXED ACIDITY'] + df['VOLATILE ACIDITY']
df['SULFUR DIOXIDE RATIO'] = df['FREE SULFUR DIOXIDE'] / df['TOTAL SULFUR DIOXIDE']
df['CHLORIDE DENSITY'] = df['CHLORIDES'] * df['DENSITY']
df['SUGAR TO ACIDITY RATIO'] = df['RESIDUAL SUGAR'] / df['TOTAL ACIDITY']
df['QUALITY CATEGORY'] = df['QUALITY'].apply(lambda x: 'low' if x <= 1 else ('medium' if x == 3 else 'high'))

# %%
df.head()
# Out:
#    FIXED ACIDITY  VOLATILE ACIDITY  CITRIC ACID  RESIDUAL SUGAR  CHLORIDES  \
# 0          7.400             0.700        0.000           1.900      0.076
# 1          7.800             0.880        0.000           2.600      0.098
# 2          7.800             0.760        0.040           2.300      0.092
# 3         11.200             0.280        0.560           1.900      0.075
# 4          7.400             0.700        0.000           1.900      0.076
#
#    FREE SULFUR DIOXIDE  TOTAL SULFUR DIOXIDE  DENSITY    PH  SULPHATES  \
# 0               11.000                34.000    0.998 3.510      0.560
# 1               25.000                67.000    0.997 3.200      0.680
# 2               15.000                54.000    0.997 3.260      0.650
# 3               17.000                60.000    0.998 3.160      0.580
# 4               11.000                34.000    0.998 3.510      0.560
#
#    ALCOHOL  QUALITY  TOTAL ACIDITY  SULFUR DIOXIDE RATIO  CHLORIDE DENSITY  \
# 0    9.400        2          8.100                 0.324             0.076
# 1    9.800        2          8.680                 0.373             0.098
# 2    9.800        2          8.560                 0.278             0.092
# 3    9.800        3         11.480                 0.283             0.075
# 4    9.400        2          8.100                 0.324             0.076
#
#    SUGAR TO ACIDITY RATIO QUALITY CATEGORY
# 0                   0.235             high
# 1                   0.300             high
# 2                   0.269             high
# 3                   0.166           medium
# 4                   0.235             high

# %%
df = pd.get_dummies(df, columns=["QUALITY CATEGORY"], drop_first=True)
df.head()
# Out:
#    FIXED ACIDITY  VOLATILE ACIDITY  CITRIC ACID  RESIDUAL SUGAR  CHLORIDES  \
# 0          7.400             0.700        0.000           1.900      0.076
# 1          7.800             0.880        0.000           2.600      0.098
# 2          7.800             0.760        0.040           2.300      0.092
# 3         11.200             0.280        0.560           1.900      0.075
# 4          7.400             0.700        0.000           1.900      0.076
#
#    FREE SULFUR DIOXIDE  TOTAL SULFUR DIOXIDE  DENSITY    PH  SULPHATES  \
# 0               11.000                34.000    0.998 3.510      0.560
# 1               25.000                67.000    0.997 3.200      0.680
# 2               15.000                54.000    0.997 3.260      0.650
# 3               17.000                60.000    0.998 3.160      0.580
# 4               11.000                34.000    0.998 3.510      0.560
#
#    ALCOHOL  QUALITY  TOTAL ACIDITY  SULFUR DIOXIDE RATIO  CHLORIDE DENSITY  \
# 0    9.400        2          8.100                 0.324             0.076
# 1    9.800        2          8.680                 0.373             0.098
# 2    9.800        2          8.560                 0.278             0.092
# 3    9.800        3         11.480                 0.283             0.075
# 4    9.400        2          8.100                 0.324             0.076
#
#    SUGAR TO ACIDITY RATIO  QUALITY CATEGORY_low  QUALITY CATEGORY_medium
# 0                   0.235                 False                    False
# 1                   0.300                 False                    False
# 2                   0.269                 False                    False
# 3                   0.166                 False                     True
# 4                   0.235                 False                    False

# %%
df[["QUALITY CATEGORY_low","QUALITY CATEGORY_medium"]] = df[["QUALITY CATEGORY_low","QUALITY CATEGORY_medium"]].astype(int)

# %%
df.head()
# Out:
#    FIXED ACIDITY  VOLATILE ACIDITY  CITRIC ACID  RESIDUAL SUGAR  CHLORIDES  \
# 0          7.400             0.700        0.000           1.900      0.076
# 1          7.800             0.880        0.000           2.600      0.098
# 2          7.800             0.760        0.040           2.300      0.092
# 3         11.200             0.280        0.560           1.900      0.075
# 4          7.400             0.700        0.000           1.900      0.076
#
#    FREE SULFUR DIOXIDE  TOTAL SULFUR DIOXIDE  DENSITY    PH  SULPHATES  \
# 0               11.000                34.000    0.998 3.510      0.560
# 1               25.000                67.000    0.997 3.200      0.680
# 2               15.000                54.000    0.997 3.260      0.650
# 3               17.000                60.000    0.998 3.160      0.580
# 4               11.000                34.000    0.998 3.510      0.560
#
#    ALCOHOL  QUALITY  TOTAL ACIDITY  SULFUR DIOXIDE RATIO  CHLORIDE DENSITY  \
# 0    9.400        2          8.100                 0.324             0.076
# 1    9.800        2          8.680                 0.373             0.098
# 2    9.800        2          8.560                 0.278             0.092
# 3    9.800        3         11.480                 0.283             0.075
# 4    9.400        2          8.100                 0.324             0.076
#
#    SUGAR TO ACIDITY RATIO  QUALITY CATEGORY_low  QUALITY CATEGORY_medium
# 0                   0.235                     0                        0
# 1                   0.300                     0                        0
# 2                   0.269                     0                        0
# 3                   0.166                     0                        1
# 4                   0.235                     0                        0

# %%
cat_cols, num_cols, cat_but_car = grab_col_names(df)
# Out:
# Observations: 1599
# Variables: 18
# cat_cols: 3
# num_cols: 15
# cat_but_car: 0
# num_but_cat: 3

# %%
y = df["QUALITY"]
X = df.drop("QUALITY", axis=1)

# %% [markdown]
# # <div style="border-radius:10px; border:#5E5772 solid; padding: 12px; background-color: #FFB6C1; font-size:100%; font-family:Comic Sans MS; font-family:Comic Sans MS; text-align:center"> STATISTICS </p>

# %%
results = sm.OLS(y, X).fit()
print(results.summary())
# Out:
#                                  OLS Regression Results
# =======================================================================================
# Dep. Variable:                QUALITY   R-squared (uncentered):                   0.961
# Model:                            OLS   Adj. R-squared (uncentered):              0.960
# Method:                 Least Squares   F-statistic:                              2424.
# Date:                Sun, 14 Apr 2024   Prob (F-statistic):                        0.00
# Time:                        20:34:45   Log-Likelihood:                         -1301.2
# No. Observations:                1599   AIC:                                      2634.
# Df Residuals:                    1583   BIC:                                      2720.
# Df Model:                          16
# Covariance Type:            nonrobust
# ===========================================================================================
#                               coef    std err          t      P>|t|      [0.025      0.975]
# -------------------------------------------------------------------------------------------
# FIXED ACIDITY               0.2205      0.038      5.785      0.000       0.146       0.295
# VOLATILE ACIDITY           -0.4277      0.070     -6.082      0.000      -0.566      -0.290
# CITRIC ACID                -0.0050      0.123     -0.041      0.967      -0.247       0.237
# RESIDUAL SUGAR              0.1366      0.059      2.323      0.020       0.021       0.252
# CHLORIDES                 339.0256    164.960      2.055      0.040      15.462     662.589
# FREE SULFUR DIOXIDE        -0.0043      0.003     -1.277      0.202      -0.011       0.002
# TOTAL SULFUR DIOXIDE       -0.0010      0.001     -0.862      0.389      -0.003       0.001
# DENSITY                     0.2626      0.595      0.441      0.659      -0.905       1.430
# PH                         -0.1401      0.151     -0.930      0.353      -0.436       0.155
# SULPHATES                   0.8042      0.096      8.373      0.000       0.616       0.993
# ALCOHOL                     0.2368      0.019     12.718      0.000       0.200       0.273
# TOTAL ACIDITY              -0.2072      0.036     -5.810      0.000      -0.277      -0.137
# SULFUR DIOXIDE RATIO        0.4401      0.185      2.380      0.017       0.077       0.803
# CHLORIDE DENSITY         -342.1409    165.406     -2.068      0.039    -666.580     -17.702
# SUGAR TO ACIDITY RATIO     -0.8001      0.471     -1.699      0.090      -1.724       0.124
# QUALITY CATEGORY_low       -1.4919      0.074    -20.123      0.000      -1.637      -1.346
# QUALITY CATEGORY_medium     0.3403      0.029     11.581      0.000       0.283       0.398
# ==============================================================================
# Omnibus:                      184.681   Durbin-Watson:                   1.719
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):              279.209
# Skew:                           0.828   Prob(JB):                     2.35e-61
# Kurtosis:                       4.203   Cond. No.                     1.10e+16
# ==============================================================================
#
# Notes:
# [1] R² is computed without centering (uncentered) since the model does not contain a constant.
# [2] Standard Errors assume that the covariance matrix of the errors is correctly specified.
# [3] The smallest eigenvalue is 4.9e-26. This might indicate that there are
# strong multicollinearity problems or that the design matrix is singular.

# %% [markdown]
# # <div style="border-radius:10px; border:#5E5772 solid; padding: 12px; background-color: #FFB6C1; font-size:100%; font-family:Comic Sans MS; font-family:Comic Sans MS; text-align:center"> SCALING </p>

# %%
scaler = MinMaxScaler()
df[num_cols] = scaler.fit_transform(df[num_cols])

df.head()
# Out:
#    FIXED ACIDITY  VOLATILE ACIDITY  CITRIC ACID  RESIDUAL SUGAR  CHLORIDES  \
# 0          0.248             0.397        0.000           0.106      0.288
# 1          0.283             0.521        0.000           0.180      0.387
# 2          0.283             0.438        0.040           0.148      0.360
# 3          0.584             0.110        0.560           0.106      0.283
# 4          0.248             0.397        0.000           0.106      0.288
#
#    FREE SULFUR DIOXIDE  TOTAL SULFUR DIOXIDE  DENSITY    PH  SULPHATES  \
# 0                0.141                 0.109    0.568 0.606      0.178
# 1                0.338                 0.237    0.494 0.362      0.271
# 2                0.197                 0.186    0.509 0.409      0.248
# 3                0.225                 0.210    0.582 0.331      0.194
# 4                0.141                 0.109    0.568 0.606      0.178
#
#    ALCOHOL  QUALITY  TOTAL ACIDITY  SULFUR DIOXIDE RATIO  CHLORIDE DENSITY  \
# 0    0.154        2          0.267                 0.360             0.288
# 1    0.215        2          0.319                 0.420             0.386
# 2    0.215        2          0.308                 0.306             0.359
# 3    0.215        3          0.570                 0.312             0.283
# 4    0.154        2          0.267                 0.360             0.288
#
#    SUGAR TO ACIDITY RATIO  QUALITY CATEGORY_low  QUALITY CATEGORY_medium
# 0                   0.076                     0                        0
# 1                   0.115                     0                        0
# 2                   0.097                     0                        0
# 3                   0.034                     0                        1
# 4                   0.076                     0                        0

# %%
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.30, random_state=42)

# %%
unique, counts = np.unique(y_test, return_counts=True)
for value, count in zip(unique, counts):
    print(f"Value: {value}, Count: {count}")
# Out:
# Value: 0, Count: 1
# Value: 1, Count: 17
# Value: 2, Count: 195
# Value: 3, Count: 200
# Value: 4, Count: 61
# Value: 5, Count: 6

# %%
rf_model = RandomForestClassifier(random_state=46).fit(X_train, y_train)
y_pred = rf_model.predict(X_test)
print(f"Accuracy: {round(accuracy_score(y_pred, y_test), 2)}")
# Out:
# Accuracy: 0.94

# %%
def plot_importance(model, features, num=len(X), save=False):
    feature_imp = pd.DataFrame({'Value': model.feature_importances_, 'Feature': features.columns})
    print(feature_imp.sort_values("Value",ascending=False))
    plt.figure(figsize=(10, 10))
    sns.set(font_scale=1)
    sns.barplot(x="Value", y="Feature", data=feature_imp.sort_values(by="Value",
                                                                     ascending=False)[0:num])
    plt.title('Features')
    plt.tight_layout()
    plt.show()
    if save:
        plt.savefig('importances.png')

plot_importance(rf_model, X)
# Out:
#     Value                  Feature
# 16  0.499  QUALITY CATEGORY_medium
# 10  0.092                  ALCOHOL
# 15  0.061     QUALITY CATEGORY_low
# 9   0.045                SULPHATES
# 1   0.043         VOLATILE ACIDITY
# 6   0.033     TOTAL SULFUR DIOXIDE
# 7   0.030                  DENSITY
# 12  0.028     SULFUR DIOXIDE RATIO
# 13  0.023         CHLORIDE DENSITY
# 2   0.022              CITRIC ACID
# 14  0.021   SUGAR TO ACIDITY RATIO
# 11  0.019            TOTAL ACIDITY
# 8   0.018                       PH
# 0   0.017            FIXED ACIDITY
# 4   0.017                CHLORIDES
# 5   0.016      FREE SULFUR DIOXIDE
# 3   0.016           RESIDUAL SUGAR

# %% [markdown]
# # <div style="border-radius:10px; border:#5E5772 solid; padding: 12px; background-color: #FFB6C1; font-size:100%; font-family:Comic Sans MS; font-family:Comic Sans MS; text-align:center"> ML MODELLING </p>

# %%
models = [('LR', LogisticRegression()),
          ('KNN', KNeighborsClassifier()),
          ('CART', DecisionTreeClassifier()),
          ('RF', RandomForestClassifier()),
          ('SVC', SVC()),
          ('GBM', GradientBoostingClassifier()),
          ("XGBoost", XGBClassifier()),
          ("LightGBM", LGBMClassifier(verbose=-1)),
          ("CatBoost", CatBoostClassifier(verbose=False))]

# %%
acclist=[]
for name, model in models:
    acc = np.mean(cross_val_score(model, X_train, y_train, cv=5, scoring="accuracy"))
    acclist.append([name,acc])
    print(f"ACC: {round(acc, 4)} ({name}) ")
# Out:
# ACC: 0.9035 (LR)
# ACC: 0.5424 (KNN)
# ACC: 0.899 (CART)
# ACC: 0.9419 (RF)
# ACC: 0.5255 (SVC)
# ACC: 0.9348 (GBM)
# ACC: 0.9321 (XGBoost)
# ACC: 0.9392 (LightGBM)
# ACC: 0.9419 (CatBoost)

# %% [markdown]
# ## <div style="border-radius:10px; border:#5E5772 solid; padding: 12px; background-color: #FFB6C1; font-size:100%; font-family:Comic Sans MS; font-family:Comic Sans MS; text-align:center"> LIGHTGBM </p>

# %%
lgbm = LGBMClassifier(verbose = -1)
lgbm_model = lgbm.fit(X_train, y_train)
y_pred_lgbm = lgbm_model.predict(X_test)

lgbm_accuracy=round(accuracy_score(y_test,y_pred), 4)*100
lgbm_accuracy
# Out:
# 94.38

# %%
cm = confusion_matrix(y_test, y_pred)

class_labels = ['Class 0', 'Class 1','Class 2','Class 3','Class 4','Class 5']

plt.figure(figsize=(8, 6))
sns.heatmap(cm, annot=True, cmap='Blues', fmt='d', xticklabels=class_labels, yticklabels=class_labels)
plt.xlabel('Predicted Labels')
plt.ylabel('True Labels')
plt.title('Confusion Matrix')
plt.show()

# %%
def plot_importance(model, features, num=len(X), save=False):
    feature_imp = pd.DataFrame({'Value': model.feature_importances_, 'Feature': features.columns})
    print(feature_imp.sort_values("Value",ascending=False))
    plt.figure(figsize=(10, 10))
    sns.set(font_scale=1)
    sns.barplot(x="Value", y="Feature", data=feature_imp.sort_values(by="Value",
                                                                     ascending=False)[0:num])
    plt.title('Features')
    plt.tight_layout()
    plt.show()
    if save:
        plt.savefig('importances.png')

plot_importance(lgbm_model, X)
# Out:
#     Value                  Feature
# 10   1728                  ALCOHOL
# 1    1587         VOLATILE ACIDITY
# 9    1450                SULPHATES
# 6    1384     TOTAL SULFUR DIOXIDE
# 12   1369     SULFUR DIOXIDE RATIO
# 14    893   SUGAR TO ACIDITY RATIO
# 2     796              CITRIC ACID
# 7     761                  DENSITY
# 8     659                       PH
# 13    640         CHLORIDE DENSITY
# 5     617      FREE SULFUR DIOXIDE
# 4     582                CHLORIDES
# 0     566            FIXED ACIDITY
# 11    542            TOTAL ACIDITY
# 3     409           RESIDUAL SUGAR
# 15    364     QUALITY CATEGORY_low
# 16    348  QUALITY CATEGORY_medium

# %% [markdown]
# ## # <div style="border-radius:10px; border:#5E5772 solid; padding: 12px; background-color: #FFB6C1; font-size:100%; font-family:Comic Sans MS; font-family:Comic Sans MS; text-align:center"> CATBOOST </p>

# %%
cat = CatBoostClassifier(learning_rate = 0.05, verbose =False)
cat_model = cat.fit(X_train, y_train)
y_pred_cat = cat_model.predict(X_test)

cat_accuracy=round(accuracy_score(y_test,y_pred), 4)*100
cat_accuracy
# Out:
# 94.38

# %%
cm = confusion_matrix(y_test, y_pred_cat)

class_labels = ['Class 0', 'Class 1','Class 2','Class 3','Class 4','Class 5']

plt.figure(figsize=(8, 6))
sns.heatmap(cm, annot=True, cmap='Blues', fmt='d', xticklabels=class_labels, yticklabels=class_labels)
plt.xlabel('Predicted Labels')
plt.ylabel('True Labels')
plt.title('Confusion Matrix')
plt.show()

# %%
def plot_importance(model, features, num=len(X), save=False):
    feature_imp = pd.DataFrame({'Value': model.feature_importances_, 'Feature': features.columns})
    print(feature_imp.sort_values("Value",ascending=False))
    plt.figure(figsize=(10, 10))
    sns.set(font_scale=1)
    sns.barplot(x="Value", y="Feature", data=feature_imp.sort_values(by="Value",
                                                                     ascending=False)[0:num])
    plt.title('Features')
    plt.tight_layout()
    plt.show()
    if save:
        plt.savefig('importances.png')

plot_importance(cat_model, X)
# Out:
#     Value                  Feature
# 16 55.213  QUALITY CATEGORY_medium
# 10  7.147                  ALCOHOL
# 15  6.427     QUALITY CATEGORY_low
# 9   4.658                SULPHATES
# 1   4.185         VOLATILE ACIDITY
# 6   3.492     TOTAL SULFUR DIOXIDE
# 12  2.726     SULFUR DIOXIDE RATIO
# 14  2.671   SUGAR TO ACIDITY RATIO
# 13  2.316         CHLORIDE DENSITY
# 7   2.101                  DENSITY
# 2   1.896              CITRIC ACID
# 11  1.549            TOTAL ACIDITY
# 8   1.366                       PH
# 5   1.182      FREE SULFUR DIOXIDE
# 0   1.178            FIXED ACIDITY
# 4   1.113                CHLORIDES
# 3   0.779           RESIDUAL SUGAR

# %% [markdown]
# # <div style="border-radius:10px; border:#5E5772 solid; padding: 12px; background-color: #FFB6C1; font-size:100%; font-family:Comic Sans MS; font-family:Comic Sans MS; text-align:center"> ANN MODELLING </p>

# %%
import tensorflow as tf
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Dense, BatchNormalization
# Out:
# 2024-04-14 20:35:43.990225: E external/local_xla/xla/stream_executor/cuda/cuda_dnn.cc:9261] Unable to register cuDNN factory: Attempting to register factory for plugin cuDNN when one has already been registered
# 2024-04-14 20:35:43.990317: E external/local_xla/xla/stream_executor/cuda/cuda_fft.cc:607] Unable to register cuFFT factory: Attempting to register factory for plugin cuFFT when one has already been registered
# 2024-04-14 20:35:44.082015: E external/local_xla/xla/stream_executor/cuda/cuda_blas.cc:1515] Unable to register cuBLAS factory: Attempting to register factory for plugin cuBLAS when one has already been registered

# %%
X_train.shape[1]
# Out:
# 17

# %%
model = tf.keras.Sequential([
    tf.keras.layers.Dense(128, input_shape=(X_train.shape[1],), activation="relu", kernel_regularizer=tf.keras.regularizers.l2(0.001)),
    tf.keras.layers.Dropout(0.2),

    tf.keras.layers.Dense(256, activation="elu", kernel_regularizer=tf.keras.regularizers.l2(0.002)),
    tf.keras.layers.Dropout(0.3),

    tf.keras.layers.Dense(512, activation="tanh", kernel_regularizer=tf.keras.regularizers.l2(0.002)),
    tf.keras.layers.Dropout(0.4),

    tf.keras.layers.Dense(512, activation="tanh", kernel_regularizer=tf.keras.regularizers.l2(0.002)),
    tf.keras.layers.Dropout(0.4),

    tf.keras.layers.Dense(128, activation="tanh", kernel_regularizer=tf.keras.regularizers.l2(0.002)),
    tf.keras.layers.Dropout(0.4),

    tf.keras.layers.Dense(32, activation="tanh", kernel_regularizer=tf.keras.regularizers.l2(0.002)),
    tf.keras.layers.Dropout(0.4),

    tf.keras.layers.Dense(8, activation="elu", kernel_regularizer=tf.keras.regularizers.l2(0.001)),
    tf.keras.layers.Dropout(0.3),

    tf.keras.layers.Dense(6, activation="softmax")
])

# Compile the model
model.compile(optimizer=tf.keras.optimizers.Adam(learning_rate=0.001),
              loss='sparse_categorical_crossentropy',
              metrics=['accuracy'])

early_stopping = tf.keras.callbacks.EarlyStopping(
    patience=10,
    restore_best_weights=True)
model.summary()
# Out:
# Model: "sequential"
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━┓
# ┃ Layer (type)                    ┃ Output Shape           ┃       Param # ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━┩
# │ dense (Dense)                   │ (None, 128)            │         2,304 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dropout (Dropout)               │ (None, 128)            │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense_1 (Dense)                 │ (None, 256)            │        33,024 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dropout_1 (Dropout)             │ (None, 256)            │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense_2 (Dense)                 │ (None, 512)            │       131,584 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dropout_2 (Dropout)             │ (None, 512)            │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense_3 (Dense)                 │ (None, 512)            │       262,656 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dropout_3 (Dropout)             │ (None, 512)            │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense_4 (Dense)                 │ (None, 128)            │        65,664 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dropout_4 (Dropout)             │ (None, 128)            │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense_5 (Dense)                 │ (None, 32)             │         4,128 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dropout_5 (Dropout)             │ (None, 32)             │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense_6 (Dense)                 │ (None, 8)              │           264 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dropout_6 (Dropout)             │ (None, 8)              │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense_7 (Dense)                 │ (None, 6)              │            54 │
# └─────────────────────────────────┴────────────────────────┴───────────────┘
#  Total params: 499,678 (1.91 MB)
#  Trainable params: 499,678 (1.91 MB)
#  Non-trainable params: 0 (0.00 B)

# %%
history = model.fit(X_train, y_train,
                    validation_data=(X_test, y_test),
                    epochs=200,
                    batch_size=32,
                    callbacks=[early_stopping],
                    verbose=1)
# Out:
# Epoch 1/200
# 20/35 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.3440 - loss: 4.1482
# WARNING: All log messages before absl::InitializeLog() is called are written to STDERR
# I0000 00:00:1713126967.904633     102 device_compiler.h:186] Compiled cluster using XLA!  This line is logged at most once for the lifetime of the process.
# W0000 00:00:1713126967.926984     102 graph_launch.cc:671] Fallback to op-by-op mode because memset node breaks graph update
# 35/35 ━━━━━━━━━━━━━━━━━━━━ 27s 387ms/step - accuracy: 0.3555 - loss: 4.0894 - val_accuracy: 0.4062 - val_loss: 3.5857
# Epoch 2/200
# 22/35 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.3766 - loss: 3.6911
# W0000 00:00:1713126981.037047     102 graph_launch.cc:671] Fallback to op-by-op mode because memset node breaks graph update
# 35/35 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.3770 - loss: 3.6844 - val_accuracy: 0.4062 - val_loss: 3.3420
# Epoch 3/200
# 35/35 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.4045 - loss: 3.4564 - val_accuracy: 0.4104 - val_loss: 3.1192
# Epoch 4/200
# 35/35 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.4244 - loss: 3.1996 - val_accuracy: 0.4938 - val_loss: 2.9255
# Epoch 5/200
# 35/35 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.3941 - loss: 3.0282 - val_accuracy: 0.4042 - val_loss: 2.7404
# Epoch 6/200
# 35/35 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.4144 - loss: 2.7718 - val_accuracy: 0.5125 - val_loss: 2.5873
# Epoch 7/200
# 35/35 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.4059 - loss: 2.6340 - val_accuracy: 0.4812 - val_loss: 2.4178
# Epoch 8/200
# 35/35 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.4379 - loss: 2.4854 - val_accuracy: 0.4792 - val_loss: 2.2671
# Epoch 9/200
# 35/35 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.4931 - loss: 2.3030 - val_accuracy: 0.4854 - val_loss: 2.1474
# Epoch 10/200
# 35/35 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.4593 - loss: 2.1907 - val_accuracy: 0.4938 - val_loss: 2.0295
# Epoch 11/200
# 35/35 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.4833 - loss: 2.0955 - val_accuracy: 0.4187 - val_loss: 1.9729
# Epoch 12/200
# 35/35 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.4506 - loss: 2.0213 - val_accuracy: 0.4875 - val_loss: 1.8526
# Epoch 13/200
# 35/35 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.4711 - loss: 1.8897 - val_accuracy: 0.5125 - val_loss: 1.7693
# Epoch 14/200
# 35/35 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.4480 - loss: 1.8274 - val_accuracy: 0.5083 - val_loss: 1.7012
# Epoch 15/200
# 35/35 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.4720 - loss: 1.7512 - val_accuracy: 0.4667 - val_loss: 1.6471
# Epoch 16/200
# 35/35 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.4594 - loss: 1.6922 - val_accuracy: 0.5104 - val_loss: 1.5800
# Epoch 17/200
# 35/35 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.4867 - loss: 1.6039 - val_accuracy: 0.4625 - val_loss: 1.5424
# Epoch 18/200
# 35/35 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.4825 - loss: 1.6161 - val_accuracy: 0.4667 - val_loss: 1.5022
# Epoch 19/200
# 35/35 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.4966 - loss: 1.5417 - val_accuracy: 0.5229 - val_loss: 1.4517
# Epoch 20/200
# 35/35 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.5165 - loss: 1.4608 - val_accuracy: 0.5208 - val_loss: 1.4199
# Epoch 21/200
# 35/35 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.5219 - loss: 1.4363 - val_accuracy: 0.4958 - val_loss: 1.4007
# Epoch 22/200
# 35/35 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.4839 - loss: 1.4487 - val_accuracy: 0.5229 - val_loss: 1.3927
# Epoch 23/200
# 35/35 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.5361 - loss: 1.4404 - val_accuracy: 0.5500 - val_loss: 1.3375
# Epoch 24/200
# 35/35 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.5330 - loss: 1.3846 - val_accuracy: 0.5521 - val_loss: 1.3128
# Epoch 25/200
# 35/35 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.5447 - loss: 1.3454 - val_accuracy: 0.5917 - val_loss: 1.2476
# Epoch 26/200
# 35/35 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.6064 - loss: 1.2814 - val_accuracy: 0.5792 - val_loss: 1.2922
# Epoch 27/200
# 35/35 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.6191 - loss: 1.2716 - val_accuracy: 0.6583 - val_loss: 1.1821
# Epoch 28/200
# 35/35 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.6731 - loss: 1.1710 - val_accuracy: 0.7812 - val_loss: 0.9362
# Epoch 29/200
# 35/35 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.7374 - loss: 1.0709 - val_accuracy: 0.8083 - val_loss: 0.8171
# Epoch 30/200
# 35/35 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.7578 - loss: 0.9814 - val_accuracy: 0.7979 - val_loss: 0.7912
# Epoch 31/200
# 35/35 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.7722 - loss: 0.9539 - val_accuracy: 0.8062 - val_loss: 0.7387
# Epoch 32/200
# 35/35 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.8149 - loss: 0.8439 - val_accuracy: 0.8229 - val_loss: 0.7017
# Epoch 33/200
# 35/35 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.8061 - loss: 0.8368 - val_accuracy: 0.7937 - val_loss: 0.7395
# Epoch 34/200
# 35/35 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.7945 - loss: 0.8498 - val_accuracy: 0.8125 - val_loss: 0.6670
# Epoch 35/200
# 35/35 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.8331 - loss: 0.7548 - val_accuracy: 0.8354 - val_loss: 0.6173
# Epoch 36/200
# 35/35 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.8384 - loss: 0.7069 - val_accuracy: 0.8229 - val_loss: 0.6531
# Epoch 37/200
# 35/35 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.8168 - loss: 0.7544 - val_accuracy: 0.8313 - val_loss: 0.6714
# Epoch 38/200
# 35/35 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.8106 - loss: 0.7803 - val_accuracy: 0.8417 - val_loss: 0.5769
# Epoch 39/200
# 35/35 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.8287 - loss: 0.6745 - val_accuracy: 0.8500 - val_loss: 0.5493
# Epoch 40/200
# 35/35 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.8454 - loss: 0.6416 - val_accuracy: 0.8458 - val_loss: 0.5673
# Epoch 41/200
# 35/35 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.8273 - loss: 0.6597 - val_accuracy: 0.8417 - val_loss: 0.5709
# Epoch 42/200
# 35/35 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.8224 - loss: 0.6825 - val_accuracy: 0.8500 - val_loss: 0.5307
# Epoch 43/200
# 35/35 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.8484 - loss: 0.5877 - val_accuracy: 0.8583 - val_loss: 0.5019
# Epoch 44/200
# 35/35 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.8142 - loss: 0.6461 - val_accuracy: 0.8562 - val_loss: 0.5114
# Epoch 45/200
# 35/35 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.8176 - loss: 0.6335 - val_accuracy: 0.8292 - val_loss: 0.6111
# Epoch 46/200
# 35/35 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.8385 - loss: 0.5997 - val_accuracy: 0.8583 - val_loss: 0.4827
# Epoch 47/200
# 35/35 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.8416 - loss: 0.5502 - val_accuracy: 0.8583 - val_loss: 0.4868
# Epoch 48/200
# 35/35 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.8574 - loss: 0.5672 - val_accuracy: 0.8458 - val_loss: 0.5290
# Epoch 49/200
# 35/35 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.8445 - loss: 0.5839 - val_accuracy: 0.8646 - val_loss: 0.4555
# Epoch 50/200
# 35/35 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.8303 - loss: 0.5784 - val_accuracy: 0.8583 - val_loss: 0.4618
# Epoch 51/200
# 35/35 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.8429 - loss: 0.5413 - val_accuracy: 0.8542 - val_loss: 0.4588
# Epoch 52/200
# 35/35 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.8518 - loss: 0.5270 - val_accuracy: 0.8542 - val_loss: 0.4662
# Epoch 53/200
# 35/35 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.8369 - loss: 0.5796 - val_accuracy: 0.8562 - val_loss: 0.4508
# Epoch 54/200
# 35/35 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.8426 - loss: 0.5390 - val_accuracy: 0.8583 - val_loss: 0.4229
# Epoch 55/200
# 35/35 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.8617 - loss: 0.5149 - val_accuracy: 0.8667 - val_loss: 0.4246
# Epoch 56/200
# 35/35 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.8667 - loss: 0.4753 - val_accuracy: 0.8500 - val_loss: 0.4721
# Epoch 57/200
# 35/35 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.8372 - loss: 0.5452 - val_accuracy: 0.8604 - val_loss: 0.4072
# Epoch 58/200
# 35/35 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.8532 - loss: 0.4953 - val_accuracy: 0.8667 - val_loss: 0.3978
# Epoch 59/200
# 35/35 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.8544 - loss: 0.4863 - val_accuracy: 0.8562 - val_loss: 0.4292
# Epoch 60/200
# 35/35 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.8585 - loss: 0.4913 - val_accuracy: 0.9021 - val_loss: 0.4301
# Epoch 61/200
# 35/35 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.8699 - loss: 0.4876 - val_accuracy: 0.8667 - val_loss: 0.4053
# Epoch 62/200
# 35/35 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.8327 - loss: 0.5108 - val_accuracy: 0.8833 - val_loss: 0.4050
# Epoch 63/200
# 35/35 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.8544 - loss: 0.4895 - val_accuracy: 0.8750 - val_loss: 0.4028
# Epoch 64/200
# 35/35 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.8530 - loss: 0.5079 - val_accuracy: 0.8875 - val_loss: 0.4056
# Epoch 65/200
# 35/35 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.8788 - loss: 0.4708 - val_accuracy: 0.8813 - val_loss: 0.3807
# Epoch 66/200
# 35/35 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.8575 - loss: 0.4714 - val_accuracy: 0.8729 - val_loss: 0.3774
# Epoch 67/200
# 35/35 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.8835 - loss: 0.4414 - val_accuracy: 0.9042 - val_loss: 0.3651
# Epoch 68/200
# 35/35 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.8742 - loss: 0.4491 - val_accuracy: 0.8875 - val_loss: 0.3793
# Epoch 69/200
# 35/35 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.8822 - loss: 0.4240 - val_accuracy: 0.9187 - val_loss: 0.3623
# Epoch 70/200
# 35/35 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.8936 - loss: 0.4355 - val_accuracy: 0.8917 - val_loss: 0.3761
# Epoch 71/200
# 35/35 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.8611 - loss: 0.4825 - val_accuracy: 0.8917 - val_loss: 0.3815
# Epoch 72/200
# 35/35 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.8640 - loss: 0.4595 - val_accuracy: 0.8667 - val_loss: 0.3901
# Epoch 73/200
# 35/35 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.8783 - loss: 0.4329 - val_accuracy: 0.8792 - val_loss: 0.3595
# Epoch 74/200
# 35/35 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.9042 - loss: 0.3772 - val_accuracy: 0.8750 - val_loss: 0.3649
# Epoch 75/200
# 35/35 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.8753 - loss: 0.4294 - val_accuracy: 0.9042 - val_loss: 0.3414
# Epoch 76/200
# 35/35 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.8793 - loss: 0.4048 - val_accuracy: 0.8917 - val_loss: 0.3733
# Epoch 77/200
# 35/35 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.8713 - loss: 0.4527 - val_accuracy: 0.8604 - val_loss: 0.4092
# Epoch 78/200
# 35/35 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.8585 - loss: 0.4909 - val_accuracy: 0.9021 - val_loss: 0.3537
# Epoch 79/200
# 35/35 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.8898 - loss: 0.4062 - val_accuracy: 0.9167 - val_loss: 0.3464
# Epoch 80/200
# 35/35 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.8690 - loss: 0.4429 - val_accuracy: 0.9146 - val_loss: 0.3333
# Epoch 81/200
# 35/35 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.8825 - loss: 0.4280 - val_accuracy: 0.9146 - val_loss: 0.3352
# Epoch 82/200
# 35/35 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.8671 - loss: 0.4233 - val_accuracy: 0.8646 - val_loss: 0.4585
# Epoch 83/200
# 35/35 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.8856 - loss: 0.4037 - val_accuracy: 0.8813 - val_loss: 0.3521
# Epoch 84/200
# 35/35 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.8834 - loss: 0.4159 - val_accuracy: 0.8833 - val_loss: 0.3527
# Epoch 85/200
# 35/35 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.8890 - loss: 0.3935 - val_accuracy: 0.8771 - val_loss: 0.3871
# Epoch 86/200
# 35/35 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.8761 - loss: 0.4393 - val_accuracy: 0.9125 - val_loss: 0.3181
# Epoch 87/200
# 35/35 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.8869 - loss: 0.4241 - val_accuracy: 0.9062 - val_loss: 0.3242
# Epoch 88/200
# 35/35 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.8815 - loss: 0.4300 - val_accuracy: 0.8917 - val_loss: 0.3398
# Epoch 89/200
# 35/35 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.8892 - loss: 0.4195 - val_accuracy: 0.8833 - val_loss: 0.3412
# Epoch 90/200
# 35/35 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.8960 - loss: 0.4092 - val_accuracy: 0.9167 - val_loss: 0.3610
# Epoch 91/200
# 35/35 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.8506 - loss: 0.4884 - val_accuracy: 0.9000 - val_loss: 0.3379
# Epoch 92/200
# 35/35 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.8806 - loss: 0.4182 - val_accuracy: 0.9042 - val_loss: 0.3360
# Epoch 93/200
# 35/35 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.8872 - loss: 0.4025 - val_accuracy: 0.8958 - val_loss: 0.3328
# Epoch 94/200
# 35/35 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.8630 - loss: 0.4521 - val_accuracy: 0.9187 - val_loss: 0.3234
# Epoch 95/200
# 35/35 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.8998 - loss: 0.3880 - val_accuracy: 0.9167 - val_loss: 0.3201
# Epoch 96/200
# 35/35 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.8758 - loss: 0.4228 - val_accuracy: 0.9208 - val_loss: 0.3300

# %%
loss_and_metrics = model.evaluate(X_test, y_test)
print(loss_and_metrics)
print('Loss = ',loss_and_metrics[0])
print('Accuracy = ',loss_and_metrics[1])
# Out:
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.9081 - loss: 0.3316
# [0.3181285262107849, 0.9125000238418579]
# Loss =  0.3181285262107849
# Accuracy =  0.9125000238418579

# %%
plt.figure(figsize=(10, 6))

train_loss = history.history['loss']
val_loss = history.history['val_loss']

epochs = range(1, len(train_loss) + 1)

plt.plot(epochs, train_loss, label="Training Loss")
plt.plot(epochs, val_loss, label="Validation Loss")

plt.title("Training and Validation Loss")
plt.xlabel("Epoch")
plt.ylabel("Loss")
plt.legend()

plt.show()

# %%
predicted = model.predict(X_test)
predicted_classes = np.argmax(predicted, axis=1)
predicted_classes
# Out:
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step
# W0000 00:00:1713126996.969808     103 graph_launch.cc:671] Fallback to op-by-op mode because memset node breaks graph update
# array([3, 2, 3, 2, 3, 2, 2, 2, 2, 3, 4, 1, 2, 2, 3, 4, 2, 2, 4, 2, 2, 3,
#        2, 3, 3, 3, 2, 3, 2, 3, 2, 2, 3, 2, 3, 2, 4, 2, 1, 3, 2, 2, 4, 2,
#        2, 3, 4, 3, 2, 3, 2, 2, 2, 2, 3, 3, 3, 2, 2, 2, 2, 2, 2, 3, 3, 2,
#        3, 2, 3, 2, 3, 1, 3, 3, 3, 2, 4, 2, 3, 3, 2, 3, 2, 3, 3, 4, 2, 3,
#        2, 1, 2, 3, 2, 2, 2, 3, 2, 3, 2, 3, 2, 2, 2, 2, 3, 4, 3, 2, 3, 2,
#        4, 2, 3, 2, 3, 2, 3, 3, 2, 3, 3, 3, 3, 3, 3, 3, 2, 3, 2, 2, 3, 2,
#        2, 4, 3, 2, 2, 2, 2, 3, 2, 3, 4, 2, 2, 2, 3, 3, 3, 2, 3, 4, 3, 2,
#        3, 2, 2, 3, 3, 3, 4, 2, 4, 2, 2, 2, 3, 3, 2, 2, 3, 2, 4, 3, 2, 3,
#        3, 2, 2, 3, 1, 3, 2, 4, 2, 2, 1, 2, 4, 3, 2, 3, 3, 4, 3, 2, 2, 3,
#        2, 4, 2, 3, 3, 2, 4, 2, 2, 2, 3, 2, 2, 2, 2, 3, 3, 2, 3, 2, 3, 3,
#        3, 3, 3, 2, 1, 2, 2, 4, 2, 2, 2, 2, 3, 3, 2, 4, 2, 3, 3, 3, 2, 1,
#        3, 4, 3, 2, 2, 3, 3, 2, 2, 3, 2, 3, 1, 2, 3, 3, 2, 3, 3, 4, 2, 3,
#        2, 4, 3, 2, 3, 3, 2, 3, 2, 3, 2, 2, 2, 3, 3, 3, 4, 2, 2, 3, 2, 2,
#        2, 3, 1, 3, 3, 4, 3, 2, 2, 3, 2, 4, 3, 3, 2, 2, 2, 3, 3, 2, 3, 3,
#        4, 4, 3, 3, 3, 3, 2, 3, 2, 2, 3, 1, 3, 3, 3, 2, 2, 2, 3, 3, 3, 3,
#        1, 4, 3, 3, 3, 2, 3, 2, 2, 2, 3, 4, 2, 2, 3, 2, 3, 2, 3, 2, 2, 3,
#        2, 3, 3, 3, 2, 3, 1, 2, 1, 2, 2, 3, 2, 3, 3, 2, 2, 2, 2, 2, 3, 2,
#        3, 3, 3, 4, 2, 3, 2, 4, 3, 3, 3, 2, 3, 2, 2, 3, 3, 2, 2, 3, 4, 3,
#        4, 3, 2, 4, 2, 2, 2, 2, 3, 2, 4, 3, 3, 2, 3, 3, 2, 3, 2, 2, 3, 3,
#        3, 2, 4, 2, 2, 2, 3, 2, 2, 2, 2, 3, 4, 3, 1, 2, 4, 2, 2, 2, 3, 3,
#        3, 3, 3, 2, 3, 2, 3, 2, 3, 3, 4, 1, 3, 2, 3, 3, 4, 2, 2, 2, 2, 3,
#        2, 2, 3, 2, 3, 2, 2, 3, 3, 1, 2, 3, 2, 2, 4, 3, 4, 1])

# %%
cm = confusion_matrix(y_test, predicted_classes)

class_labels = ['Class 0', 'Class 1','Class 2','Class 3','Class 4','Class 5']

plt.figure(figsize=(8, 6))
sns.heatmap(cm, annot=True, cmap='Blues', fmt='d', xticklabels=class_labels, yticklabels=class_labels)
plt.xlabel('Predicted Labels')
plt.ylabel('True Labels')
plt.title('Confusion Matrix')
plt.show()

# %% [markdown]
# # <div style="border-radius:10px; border:#5E5772 solid; padding: 12px; background-color: #FFB6C1; font-size:100%; font-family:Comic Sans MS; font-family:Comic Sans MS; text-align:center"> H2O AUTOML </p>

# %%
import h2o
from h2o.automl import H2OAutoML

# %%
h2o.init()
h2o_df = h2o.H2OFrame(df)
h2o_df
# Out:
# Checking whether there is an H2O instance running at http://localhost:54321..... not found.
# Attempting to start a local H2O server...
#   Java Version: openjdk version "11.0.22" 2024-01-16; OpenJDK Runtime Environment (build 11.0.22+7-post-Ubuntu-0ubuntu220.04.1); OpenJDK 64-Bit Server VM (build 11.0.22+7-post-Ubuntu-0ubuntu220.04.1, mixed mode, sharing)
#   Starting server from /opt/conda/lib/python3.10/site-packages/h2o/backend/bin/h2o.jar
#   Ice root: /tmp/tmpzjsv589w
#   JVM stdout: /tmp/tmpzjsv589w/h2o_unknownUser_started_from_python.out
#   JVM stderr: /tmp/tmpzjsv589w/h2o_unknownUser_started_from_python.err
#   Server is running at http://127.0.0.1:54321
# Connecting to H2O server at http://127.0.0.1:54321 ... successful.
# --------------------------  ----------------------------------
# H2O_cluster_uptime:         02 secs
# H2O_cluster_timezone:       Etc/UTC
# H2O_data_parsing_timezone:  UTC
# H2O_cluster_version:        3.46.0.1
# H2O_cluster_version_age:    1 month and 1 day
# H2O_cluster_name:           H2O_from_python_unknownUser_dvql3q
# H2O_cluster_total_nodes:    1
# H2O_cluster_free_memory:    7.250 Gb
# H2O_cluster_total_cores:    4
# H2O_cluster_allowed_cores:  4
# H2O_cluster_status:         locked, healthy
# H2O_connection_url:         http://127.0.0.1:54321
# H2O_connection_proxy:       {"http": null, "https": null}
# H2O_internal_security:      False
# Python_version:             3.10.13 final
# --------------------------  ----------------------------------
# Parse progress: |████████████████████████████████████████████████████████████████| (done) 100%
#   FIXED ACIDITY    VOLATILE ACIDITY    CITRIC ACID    RESIDUAL SUGAR    CHLORIDES    FREE SULFUR DIOXIDE    TOTAL SULFUR DIOXIDE    DENSITY        PH    SULPHATES    ALCOHOL    QUALITY    TOTAL ACIDITY    SULFUR DIOXIDE RATIO    CHLORIDE DENSITY    SUGAR TO ACIDITY RATIO    QUALITY CATEGORY_low    QUALITY CATEGORY_medium
# ---------------  ------------------  -------------  ----------------  -----------  ---------------------  ----------------------  ---------  --------  -----------  ---------  ---------  ---------------  ----------------------  ------------------  ------------------------  ----------------------  -------------------------
#        0.247788            0.39726            0            0.105652      0.287964               0.140845               0.108632    0.567548  0.606299     0.178295   0.153846          2         0.266906                0.360494            0.287693                 0.0757664                       0                          0
#        0.283186            0.520548           0            0.179609      0.386952               0.338028               0.236663    0.494126  0.362205     0.271318   0.215385          2         0.318854                0.419943            0.386014                 0.115292                        0                          0
#        0.283186            0.438356           0.04         0.147913      0.359955               0.197183               0.186227    0.508811  0.409449     0.248062   0.215385          2         0.308106                0.305664            0.359188                 0.0965256                       0                          0
#        0.584071            0.109589           0.56         0.105652      0.283465               0.225352               0.209505    0.582232  0.330709     0.193798   0.215385          3         0.569637                0.312322            0.283271                 0.0337519                       0                          1
#        0.247788            0.39726            0            0.105652      0.287964               0.140845               0.108632    0.567548  0.606299     0.178295   0.153846          2         0.266906                0.360494            0.287693                 0.0757664                       0                          0
#        0.247788            0.369863           0            0.0950872     0.283465               0.169014               0.131911    0.567548  0.606299     0.178295   0.153846          2         0.263323                0.362257            0.283204                 0.0689268                       0                          0
#        0.292035            0.328767           0.06         0.0739567     0.256468               0.197183               0.205626    0.464758  0.440945     0.100775   0.153846          2         0.302732                0.277452            0.255834                 0.0475798                       0                          0
#        0.238938            0.363014           0            0.0316957     0.23847                0.197183               0.0581959   0.332599  0.511811     0.108527   0.246154          4         0.253471                0.828794            0.237376                 0.0248932                       0                          0
#        0.283186            0.315068           0.02         0.116218      0.274466               0.112676               0.0465567   0.494126  0.488189     0.186047   0.169231          4         0.291984                0.571984            0.273897                 0.0782579                       0                          0
#        0.256637            0.260274           0.36         0.549392      0.265467               0.225352               0.372454    0.567548  0.480315     0.364341   0.323077          2         0.257949                0.172503            0.265247                 0.396935                        0                          0
# [1599 rows x 18 columns]

# %%
X = list(h2o_df.columns[:-1])
y = 'QUALITY'

# %%
h2o_automl = H2OAutoML(max_models=15, seed=1,
                       keep_cross_validation_models=True,
                       keep_cross_validation_predictions=True,
                       keep_cross_validation_fold_assignment=True)
h2o_automl.train(x=X, y=y, training_frame=h2o_df)
# Out:
# AutoML progress: |███████████████████████████████████████████████████████████████| (done) 100%
# Model Details
# =============
# H2OStackedEnsembleEstimator : Stacked Ensemble
# Model Key: StackedEnsemble_BestOfFamily_1_AutoML_1_20240414_203647
#
#
# Model Summary for Stacked Ensemble:
# key                                        value
# -----------------------------------------  ----------------
# Stacking strategy                          cross_validation
# Number of base models (used / total)       5/6
# # GBM base models (used / total)           1/1
# # XGBoost base models (used / total)       1/1
# # DRF base models (used / total)           2/2
# # GLM base models (used / total)           1/1
# # DeepLearning base models (used / total)  0/1
# Metalearner algorithm                      GLM
# Metalearner fold assignment scheme         Random
# Metalearner nfolds                         5
# Metalearner fold_column
# Custom metalearner hyperparameters         None
#
# ModelMetricsRegressionGLM: stackedensemble
# ** Reported on train data. **
#
# MSE: 0.025917703463423158
# RMSE: 0.160989761983249
# MAE: 0.11789983288428241
# RMSLE: 0.04620842815486557
# Mean Residual Deviance: 0.025917703463423158
# R^2: 0.9602343163178452
# Null degrees of freedom: 1598
# Residual degrees of freedom: 1593
# Null deviance: 1042.165103189486
# Residual deviance: 41.44240783801363
# AIC: -1289.1081615935486
#
# ModelMetricsRegressionGLM: stackedensemble
# ** Reported on cross-validation data. **
#
# MSE: 0.23544473949067268
# RMSE: 0.48522648267656693
# MAE: 0.35385343168546163
# RMSLE: 0.13753551443818401
# Mean Residual Deviance: 0.23544473949067268
# R^2: 0.6387557621211845
# Null degrees of freedom: 1598
# Residual degrees of freedom: 1593
# Null deviance: 1043.7907414307315
# Residual deviance: 376.4761384455856
# AIC: 2239.1652363854587
#
# Cross-Validation Metrics Summary:
#                         mean      sd         cv_1_valid    cv_2_valid    cv_3_valid    cv_4_valid    cv_5_valid
# ----------------------  --------  ---------  ------------  ------------  ------------  ------------  ------------
# aic                     456.973   42.2309    444.846       524.963       467.267       417.989       429.8
# loglikelihood           0         0          0             0             0             0             0
# mae                     0.354648  0.0280033  0.345491      0.404115      0.347037      0.340896      0.335704
# mean_residual_deviance  0.235095  0.0313716  0.226491      0.289061      0.233175      0.214622      0.212127
# mse                     0.235095  0.0313716  0.226491      0.289061      0.233175      0.214622      0.212127
# null_deviance           208.758   14.8535    198.485       192.392       219.739       205.056       228.119
# r2                      0.635391  0.0689753  0.63817       0.518702      0.649618      0.674377      0.696087
# residual_deviance       75.2086   10.3513    71.7975       92.4994       76.4815       66.7474       68.5169
# rmse                    0.484056  0.0313161  0.47591       0.537644      0.482882      0.463273      0.460572
# rmsle                   0.137596  0.0022276  0.136341      0.140369      0.13608       0.13963       0.135559
#
# [tips]
# Use `model.explain()` to inspect the model.
# --
# Use `h2o.display.toggle_user_tips()` to switch on/off this section.

# %%
best_model = h2o_automl.leader
print(best_model.model_id)
# Out:
# StackedEnsemble_BestOfFamily_1_AutoML_1_20240414_203647

# %%
learning_curve_plot = best_model.learning_curve_plot()

# %%
train, valid = h2o_df.split_frame(ratios=[0.8])

predictions = best_model.predict(valid)
performance = best_model.model_performance(valid)

print(performance)
# Out:
# stackedensemble prediction progress: |███████████████████████████████████████████| (done) 100%
# ModelMetricsRegressionGLM: stackedensemble
# ** Reported on test data. **
#
# MSE: 0.0280048385561752
# RMSE: 0.16734646263418657
# MAE: 0.12177462618792739
# RMSLE: 0.05011751907872761
# Mean Residual Deviance: 0.0280048385561752
# R^2: 0.9560908205331049
# Null degrees of freedom: 322
# Residual degrees of freedom: 317
# Null deviance: 208.509488223761
# Residual deviance: 9.04556285364459
# AIC: -224.21279449494833

# %%
performance = best_model.model_performance(valid)
classification_report = performance.show()
print(classification_report)
# Out:
# ModelMetricsRegressionGLM: stackedensemble
# ** Reported on test data. **
#
# MSE: 0.0280048385561752
# RMSE: 0.16734646263418657
# MAE: 0.12177462618792739
# RMSLE: 0.05011751907872761
# Mean Residual Deviance: 0.0280048385561752
# R^2: 0.9560908205331049
# Null degrees of freedom: 322
# Residual degrees of freedom: 317
# Null deviance: 208.509488223761
# Residual deviance: 9.04556285364459
# AIC: -224.21279449494833
# None

# %%
h2o.cluster().shutdown()
# Out:
# H2O session _sid_9bd0 closed.
